# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('http://data.insideairbnb.com/switzerland/vd/vaud/2019-02-18/visualisations/listings.csv',header=0,sep=',',index_col=0)
df.head(5)
# Out:
#                                    name  host_id    host_name  \
# id
# 7381                    Chalet Chocolat    19480        Paula
# 26809   Quiet bedroom, private bathroom    94917         Eric
# 50123          Not Available any longer   229512  Christopher
# 129558          Vos vacances à Lausanne   638930        Carol
# 198351                        Cosy Room   967965     Isabelle
#
#           neighbourhood_group   neighbourhood  latitude  longitude  \
# id
# 7381                    Aigle   Ormont-Dessus  46.35497    7.13198
# 26809             Lavaux-Oron           Pully  46.52228    6.66425
# 50123                    Nyon  Mont-sur-Rolle  46.47540    6.32883
# 129558               Lausanne        Lausanne  46.53873    6.62034
# 198351  Riviera-Pays-d'Enhaut        Montreux  46.44828    6.89744
#
#               room_type  price  minimum_nights  number_of_reviews last_review  \
# id
# 7381    Entire home/apt    110               3                 16  2018-11-07
# ...

# %%
print(df.shape)
# Out:
# (3825, 15)

# %%
df2=df['neighbourhood'].value_counts()
df2.to_csv('df3')
df4=pd.read_csv('df3',header=None)
df4.columns=['neighbourhood','Count']
display(df4)
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#                neighbourhood  Count
# 0                   Lausanne   1052
# 1                   Montreux    314
# 2                      Ollon    284
# 3                      Gryon    125
# 4                     Leysin    113
# 5                      Vevey    104
# 6                       Nyon     82
# 7              Ormont-Dessus     76
# 8              Château-d'Oex     67
# 9              Renens (Vaud)     61
# 10                     Pully     58
# 11                     Lutry     57
# 12                    Morges     49
# 13           Bourg-en-Lavaux     44
# 14                 Rougemont     41
# 15          La Tour-de-Peilz     41
# 16           Ecublens (Vaud)     39
# ...

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
latitude = 46.62
longitude = 6.55
sanfran_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# %%
world_geo = r'http://data.insideairbnb.com/switzerland/vd/vaud/2019-02-18/visualisations/neighbourhoods.geojson'
threshold_scale = np.linspace(df4['Count'].min(),
                              df4['Count'].max(),
                              6, dtype=int)
threshold_scale = threshold_scale.tolist() 
threshold_scale[-1] = threshold_scale[-1] + 1 
sanfran_map.choropleth(
    geo_data=world_geo,
    data=df4,
    columns=['neighbourhood','Count'],
    key_on='feature.properties.neighbourhood',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Airbnb in Geneva'
)

sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
